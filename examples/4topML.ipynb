# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

import os.path
import pickle
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import matplotlib        as mpl
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.ensemble        import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics         import roc_curve

# Plot settings
mpl.rcParams['legend.frameon' ] = False
mpl.rcParams['legend.fontsize'] = 'xx-large'
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['axes.titlesize' ] = 18
mpl.rcParams['axes.labelsize' ] = 18
mpl.rcParams['lines.linewidth'] = 2.5


# Useful functions
from utils import *

# %%
data = pd.read_csv('4topSM.csv')
df = pd.DataFrame(data)
df = remove_bjets_info(df) #drop b-jets info as it is really chitting at the truth level
cols = df.columns.tolist()
cols = cols[1:-1] + [cols[0]]
df = df[cols]
df.head()
# Out:
#            ht  njet  nlep         met   met_phi     lep_pt0     lep_pt1  \
# 0  363.195618     6     0   77.773085  1.056524    0.000000    0.000000
# 1  739.406982     9     0   80.217866 -2.799677    0.000000    0.000000
# 2  756.153748     9     1   51.067984  1.685508  125.348915    0.000000
# 3  708.742126     5     2   93.307299  3.023522   40.827286  169.840958
# 4  567.742065     5     3  193.714731  2.289553  105.930557   25.705399
#
#      lep_pt2  lep_pt3  lep_pt4     ...       jet_phi1  jet_phi2  jet_phi3  \
# 0   0.000000      0.0      0.0     ...      -1.353635 -0.062811 -2.819673
# 1   0.000000      0.0      0.0     ...      -2.822858  0.774919  0.008384
# 2   0.000000      0.0      0.0     ...       0.486200 -0.327779  1.340544
# 3   0.000000      0.0      0.0     ...      -1.497974 -2.450683 -1.618584
# 4  83.422684      0.0      0.0     ...      -1.440520  2.363418 -2.278268
#
#    jet_phi4  jet_phi5  jet_phi6  jet_phi7  jet_phi8  jet_phi9        m4top
# 0 -2.431048 -0.942151  0.000000  0.000000  0.000000       0.0  1480.240498
# 1 -1.466113 -1.142968  2.238023 -0.308192 -2.853332       0.0  1279.838371
# 2 -2.613982 -1.496786  2.270387  1.722179  1.651971       0.0   995.802801
# 3 -1.246808  0.000000  0.000000  0.000000  0.000000       0.0  1382.241903
# 4 -1.583575  0.000000  0.000000  0.000000  0.000000       0.0  2706.690433
#
# [5 rows x 51 columns]

# %%
data_ttV = pd.read_csv('ttV.csv')
df_ttV = pd.DataFrame(data_ttV)
df_ttV = remove_bjets_info(df_ttV)
cols = df_ttV.columns.tolist()
cols = cols[1:-1] + [cols[0]]
df_ttV = df_ttV[cols]
df_ttV.head()
# Out:
#            ht  njet  nlep        met   met_phi    lep_pt0  lep_pt1  lep_pt2  \
# 0  898.933899     8     1  22.632032 -0.086053  88.720406      0.0      0.0
# 1  563.983948     4     0  26.726042  1.816308   0.000000      0.0      0.0
# 2  303.772491     6     0   0.000000  0.000000   0.000000      0.0      0.0
# 3  515.249084     6     0  32.442406  1.914836   0.000000      0.0      0.0
# 4  441.026398     5     0  23.852623 -1.567359   0.000000      0.0      0.0
#
#    lep_pt3  lep_pt4  ...    jet_phi1  jet_phi2  jet_phi3  jet_phi4  jet_phi5  \
# 0      0.0      0.0  ...   -0.193707 -0.657140 -2.834816 -0.800857  2.978076
# 1      0.0      0.0  ...   -0.032695  0.292401  1.266840  0.000000  0.000000
# 2      0.0      0.0  ...   -2.554685  0.312499  2.009220 -2.592917  2.668648
# 3      0.0      0.0  ...   -1.702243 -1.348230 -1.403107  0.429677 -2.862985
# 4      0.0      0.0  ...   -3.022666 -1.603236  0.891441  1.432376  0.000000
#
#    jet_phi6  jet_phi7  jet_phi8  jet_phi9  m4top
# 0 -2.394817  1.907061       0.0       0.0  -99.0
# 1  0.000000  0.000000       0.0       0.0  -99.0
# 2  0.000000  0.000000       0.0       0.0  -99.0
# 3  0.000000  0.000000       0.0       0.0  -99.0
# 4  0.000000  0.000000       0.0       0.0  -99.0
#
# [5 rows x 51 columns]

# %%
compare_4top_ttV_distributions(df,df_ttV,['ht','njet','jet_pt0','nlep','lep_pt0','met'],'nlep>0')

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.hist(df['m4top'], bins=100, histtype='step', linewidth=2.5,label='tttt')
plt.subplot(142)
plt.scatter(df['jet_pt1'],df['m4top'])
plt.subplot(143)
plt.scatter(df['lep_pt1'],df['m4top'])
plt.subplot(144)
plt.scatter(df['met'],df['m4top'])

# %%
# Features and target
dataX = df.drop('m4top',axis=1)
dataY = df['m4top']

# Preparing cross validation samples
trainX, testX, trainY, testY = train_test_split(dataX, dataY, random_state=42, train_size=0.5)

# %%
# Random forest
if (os.path.exists('random_forest_regression.dat')):
    rf_regre = open_model_from_file('random_forest_regression.dat')
else:
    rf_regre = RandomForestRegressor(n_estimators=500,n_jobs=-1,max_depth=10).fit(trainX, trainY)
    save_model_in_file(rf_regre,'random_forest_regression.dat')

# Adaptative boosting
from sklearn.ensemble    import AdaBoostRegressor
from sklearn.tree        import DecisionTreeRegressor
if (os.path.exists('adaboost_regression.dat')):
    ab_regre = open_model_from_file('adaboost_regression.dat')
else:
    ab_regre = AdaBoostRegressor(n_estimators=500, base_estimator=DecisionTreeRegressor(max_depth=10)).fit(trainX, trainY)
    save_model_in_file(ab_regre,'adaboost_regression.dat')

# Gradient boosting
from sklearn.ensemble import GradientBoostingRegressor
if (os.path.exists('gradboost_regression.dat')):
    gb_regre = open_model_from_file('gradboost_regression.dat')
else:
    gb_regre = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1, max_depth=10).fit(trainX,trainY)
    save_model_in_file(gb_regre,'gradboost_regression.dat')

# %%
plot_perf_randomforest_vs_ntree(rf_regre,trainX,trainY,testX,testY)

# %%
plot_prediction_vs_truth(rf_regre,testX,testY)

# %%
plot_prediction_vs_truth(ab_regre,testX,testY)

# %%
plot_prediction_vs_truth(gb_regre,testX,testY)

# %%
plot_prediction_ndim(rf_regre,testX,testY,trainX,trainY)

# %%
plt.figure(figsize=(20,6))
regressors=[[rf_regre,'RandForest'],[gb_regre,'GradientBoost'],[ab_regre,'AdaBoost']]
dataX_ttV = df_ttV.drop('m4top',axis=1)

i=0
for regre,name in regressors:
    i=i+1
    plt.subplot(1,3,i)
    plt.hist(regre.predict(dataX_ttV), density=True, bins=np.linspace(0,6000,60), histtype='step', linewidth=2.5, label='ttV')
    plt.hist(regre.predict(trainX)   , density=True, bins=np.linspace(0,6000,60), histtype='step', linewidth=2.5, label='4top')
    plt.title(name)
    plt.legend()

# %%
# Try classification
sig_labelled = df.drop(['m4top'],axis=1)
sig_labelled['isSig'] = 1
bkg_labelled = df_ttV.drop(['m4top'],axis=1)
bkg_labelled['isSig'] = 0
data  = pd.concat( [sig_labelled,bkg_labelled] )
dataX_clf = data.drop('isSig',axis=1)
dataY_clf = data['isSig']

#dataX_clf = dataX_clf[['ht','met','lep_pt3','jet_pt1','jet_pt6']]

# Preparing cross validation samples
trainX_clf, testX_clf, trainY_clf, testY_clf = train_test_split(dataX_clf, dataY_clf, random_state=42, train_size=0.5)

# %%
if (os.path.exists('random_forest_classification.dat')):
    rf_clf = open_model_from_file('random_forest_classification.dat')
else:
    rf_clf = RandomForestRegressor(n_estimators=200,n_jobs=-1,max_depth=15).fit(trainX_clf, trainY_clf)
    save_model_in_file(rf_clf,'random_forest_classification.dat')

# %%
# look at the features importance
for feature, importance in zip(trainX_clf.columns,rf_clf.feature_importances_):
    if (importance>0.01):
        print (feature, importance)
# Out:
# ht 0.122870992907
# met 0.0842841140054
# met_phi 0.0135044903705
# lep_pt0 0.0299748550855
# jet_pt0 0.0135878650964
# jet_pt1 0.0114704395998
# jet_pt2 0.0132488009177
# jet_pt3 0.0143477761369
# jet_pt4 0.0197983523959
# jet_pt5 0.0262277582367
# jet_pt6 0.38503988342
# jet_pt7 0.0120152357371
# jet_pt8 0.017462781184
# jet_pt9 0.010847248706
# jet_eta0 0.0131297447356
# jet_eta1 0.0131616267325
# jet_eta2 0.0127535227266
# jet_eta3 0.0133183456947
# jet_eta4 0.01218381564
# jet_eta5 0.0105145875038
# jet_phi0 0.0130189215396
# jet_phi1 0.013731125223
# jet_phi2 0.0138590234248
# jet_phi3 0.0142618904978
# jet_phi4 0.0126534987807
# jet_phi5 0.0100812316538

# %%
plot_perf_randomforest_vs_ntree(rf_clf,trainX_clf,trainY_clf,testX_clf,testY_clf)

# %%
plt.figure(figsize=(8,6))
plt.hist(rf_clf.predict(testX_clf[testY_clf==1]), histtype='step', bins=np.linspace(-0.2,1.2,35), linewidth=2.5, label='4top')
plt.hist(rf_clf.predict(testX_clf[testY_clf==0]), histtype='step', bins=np.linspace(-0.2,1.2,35), linewidth=2.5, label='ttV')
plt.legend(loc='center')
plt.xlabel('Prediction of IsSignal')
# Out:
# Text(0.5,0,'Prediction of IsSignal')

# %%
selection        = 'njet>4 and nlep>0'
VariableToTest   = ['ht','njet','lep_pt1','jet_pt1','jet_pt6']
RegressorsToTest = [[rf_regre,'RandForest (m4top)'],[ab_regre,'AdaBoost (m4top)'],[gb_regre,'GradientBoost (m4top)'],[rf_clf,'RandForest (classifier)']]
plot_roc_curves(df.drop('m4top',axis=1),df_ttV.drop('m4top',axis=1), VariableToTest, RegressorsToTest,selection)
